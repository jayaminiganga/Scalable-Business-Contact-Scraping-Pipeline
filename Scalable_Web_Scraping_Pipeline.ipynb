# %% [markdown]
# # Directory Crawling

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import pandas as pd
import os
import re


SECTOR = "wine" # Sector to search for
OUT_DIR = "outputs" ## Folder to save output files
os.makedirs(OUT_DIR, exist_ok=True)

START_URL = "https://www.europages.co.uk/en/search?q=Wine+producers"
MAX_PAGES = 5 # Number of pages to crawl

# Setup headless Chrome (browser runs without opening a window)
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome(options=options)

def extract_company_links(html):
    """Extracts company profile links from a given HTML page."""
    soup = BeautifulSoup(html, "lxml")
    links = set()

    # Pattern 1: Old format with .html
    pattern_old = re.compile(
        r"^https://www\.europages\.co\.uk/[^/]+/[A-Z0-9]+-\d+\.html$", re.IGNORECASE
    )

    # Pattern 2: New format without .html
    pattern_new = re.compile(
        r"^https://www\.europages\.co\.uk/en/company/[a-z0-9-]+-\d+$", re.IGNORECASE
    )

    # Find all <a> tags and check if they match company profile links
    for a in soup.find_all("a", href=True):
        href = a["href"].strip()
        if href.startswith("/"): # Convert relative links to full URLs
            href = "https://www.europages.co.uk" + href

        # Add link if it matches old or new format
        if pattern_old.match(href) or pattern_new.match(href):
            links.add(href)

    return links


def crawl_directory(start_url, max_pages):
        """Crawl directory pages and collect all company profile links."""

    all_links = set()
    page_url = start_url

    for page in range(1, max_pages + 1):
        print(f"[crawl] Page {page}: {page_url}")
        driver.get(page_url)
        time.sleep(3)  # # Wait for JavaScript content to load
        html = driver.page_source
        links = extract_company_links(html)
        print(f"  found {len(links)} links")
        all_links.update(links)
        
        # Construct next page URL (pagination handling)
        page_url = f"https://www.europages.co.uk/en/search/page/{page+1}?q=Wine+producers"

    print(f"[done] Collected {len(all_links)} unique links")
    return sorted(all_links)

def export_links_csv(links, sector):
    """Save profile links to CSV file."""
    path = os.path.join(OUT_DIR, f"links_{sector}.csv")
    pd.DataFrame({"url": links}).to_csv(path, index=False)
    print(f"[save] {path}")

if __name__ == "__main__":
    try:
        # Crawl directory and extract links
        links = crawl_directory(START_URL, MAX_PAGES)
        
        # Save links to CSV
        export_links_csv(links, SECTOR)
    finally:
        # Close the browser after execution
        driver.quit()
# Out:
# [crawl] Page 1: https://www.europages.co.uk/en/search?q=Wine+producers
#   found 30 links
# [crawl] Page 2: https://www.europages.co.uk/en/search/page/2?q=Wine+producers
#   found 30 links
# [crawl] Page 3: https://www.europages.co.uk/en/search/page/3?q=Wine+producers
#   found 30 links
# [crawl] Page 4: https://www.europages.co.uk/en/search/page/4?q=Wine+producers
#   found 30 links
# [crawl] Page 5: https://www.europages.co.uk/en/search/page/5?q=Wine+producers
#   found 30 links
# [done] Collected 150 unique links
# [save] outputs\links_wine.csv

# %% [markdown]
# # Scrape company profile: name, country, and emails.

# %%
import pandas as pd
import re
import time
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Setup
SECTOR = "wine" # Sector to search for
OUT_DIR = "outputs" # Folder to save results
LINKS_CSV = os.path.join(OUT_DIR, f"links_{SECTOR}.csv") # Input file containing company profile links
EMAILS_CSV = os.path.join(OUT_DIR, f"emails_{SECTOR}.csv") # Output file to save emails

# Setup Chrome WebDriver in headless mode (no browser window)
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome(options=options)

def extract_company_info(soup):
    """Extract company name and country from company profile page."""
    # Get company name from <a> with class 'company-name'
    company_name_tag = soup.find("a", class_="company-name")
    company_name = company_name_tag.text.strip() if company_name_tag else "N/A"
    
    # Get country from div with class 'flex gap-1 items-center mt-0.5'
    country_div = soup.find("div", class_="flex gap-1 items-center mt-0.5")
    country = "N/A"
    if country_div:
        spans = country_div.find_all("span")
        if len(spans) > 1:
            country = spans[1].text.strip()
    return company_name, country

def get_email_from_page(url):
    """Extract multiple emails from a given page (excluding generic ones)."""
    driver.get(url)
    time.sleep(2) # wait for page load
    soup = BeautifulSoup(driver.page_source, "lxml")
    text = soup.get_text(" ", strip=True)

    # Find emails using regex
    emails = re.findall(r'[\w\.-]+@[\w\.-]+\.\w+', text)
    
    # Filter out generic emails
    filtered = [e for e in emails if not e.lower().startswith(("info@", "contact@", "sales@", "admin@"))]

    # Return unique list of emails (prefer filtered, fallback to all emails)
    return list(set(filtered if filtered else emails))

def find_contact_or_impressum_link(soup):
    """Find links that may lead to contact/impressum pages in multiple languages."""
    keywords = ["contact", "kontakt", "contatti", "scrivici", "impressum"]
    for a in soup.find_all("a", href=True):
        text = a.get_text(strip=True).lower()
        href = a['href'].lower()
        if any(k in text for k in keywords) or any(k in href for k in keywords):
            return a['href']
    return None

def scrape_profile(url):
    """Scrape company profile: name, country, and emails."""

    print(f"Scraping: {url}")
    try:
        # Load profile page
        driver.get(url)
        time.sleep(3)
        soup = BeautifulSoup(driver.page_source, "lxml")

        # Extract company name and country
        company_name, country = extract_company_info(soup)

        # Find 'Visit website' link
        website_link = None
        for a in soup.find_all("a", href=True):
            if a.text.strip().lower().startswith("visit website"):
                website_link = a['href']
                break
        if not website_link:
            print(f"Visit website link not found for {company_name}")
            return None

        # Navigate to company website
        website_url = urljoin(url, website_link)
        driver.get(website_url)
        time.sleep(3)
        website_soup = BeautifulSoup(driver.page_source, "lxml")

        # Find contact or impressum link
        contact_link = find_contact_or_impressum_link(website_soup)
        if contact_link:
            contact_url = urljoin(website_url, contact_link)
        else:
            contact_url = website_url  # fallback

        # Try extracting email from contact page
        emails = get_email_from_page(contact_url)

        # If still no email, check Impressum page explicitly
        if not emails:
            for a in website_soup.find_all("a", href=True):
                if "impressum" in a['href'].lower():
                    impressum_url = urljoin(website_url, a['href'])
                    emails = get_email_from_page(impressum_url)
                    break

        if company_name and emails:
            return {"Name": company_name, "Country": country, "Email": "; ".join(emails)}
        else:
            print(f"Incomplete data for {company_name} at {url}")
            return None

    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

def main():
    """Main function: read company links, scrape profiles, and save results."""
    # Read company profile links from CSV
    df_links = pd.read_csv(LINKS_CSV)
    profile_urls = df_links["url"].drop_duplicates().tolist()

    results = []
    for url in profile_urls:
        data = scrape_profile(url)
        if data:
            results.append(data)
            
    # Save results to CSV (avoid duplicates by email)
    df = pd.DataFrame(results)
    df.drop_duplicates(subset=["Email"], inplace=True)
    if not os.path.exists(OUT_DIR):
        os.makedirs(OUT_DIR)
    df.to_csv(EMAILS_CSV, index=False)
    print(f"Saved output to {EMAILS_CSV}")

if __name__ == "__main__":
    main()
    driver.quit()
# Out:
# Scraping: https://www.europages.co.uk/ACRI-WINE-SERVICE/00000005388822-707741001.html
# Incomplete data for ACRI WINE SERVICE at https://www.europages.co.uk/ACRI-WINE-SERVICE/00000005388822-707741001.html
# Scraping: https://www.europages.co.uk/ADEGA-COOPERATIVA-DE-ALMEIRIM-CRL/PRT013955-00101.html
# Scraping: https://www.europages.co.uk/ADEGA-COOPERATIVA-DE-PONTE-DE-BARCA-CRL/00000004477533-311265001.html
# Incomplete data for ADEGA COOPERATIVA DE PONTE DE BARCA, CRL at https://www.europages.co.uk/ADEGA-COOPERATIVA-DE-PONTE-DE-BARCA-CRL/00000004477533-311265001.html
# Scraping: https://www.europages.co.uk/AG-VINS/00000005521534-001.html
# Scraping: https://www.europages.co.uk/AMORIM-CORK/PRT004475-00101.html
# Scraping: https://www.europages.co.uk/ARTEBOTTI-DI-MAURIZIO-CANNATA/00000005401987-733065001.html
# Scraping: https://www.europages.co.uk/BARRISPT/00000005420863-756922001.html
# Scraping: https://www.europages.co.uk/BASTIDE-DE-FAVE/00000005451877-794868001.html
# Scraping: https://www.europages.co.uk/BESTPACK-PACKAGING-EXPORT/00000005470722-845170001.html
# Incomplete data for BESTPACK PACKAGING & EXPORT at https://www.europages.co.uk/BESTPACK-PACKAGING-EXPORT/00000005470722-845170001.html
# Scraping: https://www.europages.co.uk/BIO-NARANJA/00000005464670-835120001.html
# Scraping: https://www.europages.co.uk/BIOWEINREICH-OKOLOGISCHER-WEINHANDEL-THOMAS-REICH/00000005445286-784014001.html
# Scraping: https://www.europages.co.uk/BOLNEY-WINE-ESTATE/00000004059205-001.html
# Scraping: https://www.europages.co.uk/BONTAP/00000005523889-001.html
# Scraping: https://www.europages.co.uk/BORFLEX-SERVICES/00000004654018-001.html
# Scraping: https://www.europages.co.uk/BRUNO-WOLHFARTH/SEAC001040967-001.html
# Scraping: https://www.europages.co.uk/CADALPE-SRL/00000003999915-270449001.html
# Scraping: https://www.europages.co.uk/CADES-PENEDES/00000003942579-001.html
# Scraping: https://www.europages.co.uk/CANTINA24/00000005376669-689084001.html
# Scraping: https://www.europages.co.uk/CAVES-SUNNENHOFFMANN/LUX006880-00101.html
# Scraping: https://www.europages.co.uk/CDA/00000004666309-467374001.html
# Scraping: https://www.europages.co.uk/CHAMPAGNE-CLAUDE-PERRARD/00000004723005-523798001.html
# Scraping: https://www.europages.co.uk/CHAMPAGNE-DORE-LEGUILLETTE/00000005447321-786544001.html
# Incomplete data for CHAMPAGNE DORÉ LÉGUILLETTE at https://www.europages.co.uk/CHAMPAGNE-DORE-LEGUILLETTE/00000005447321-786544001.html
# Scraping: https://www.europages.co.uk/CHARDONNAY-MEERDAEL/BEL102909-00101.html
# Scraping: https://www.europages.co.uk/CHATEAU-LA-CAMINADE/00000004672478-001.html
# Incomplete data for CHÂTEAU LA CAMINADE at https://www.europages.co.uk/CHATEAU-LA-CAMINADE/00000004672478-001.html
# Scraping: https://www.europages.co.uk/CHATEAUX-ET-VINS-DE-BORDEAUX/00000005520965-001.html
# Incomplete data for CHÂTEAUX ET VINS DE BORDEAUX at https://www.europages.co.uk/CHATEAUX-ET-VINS-DE-BORDEAUX/00000005520965-001.html
# Scraping: https://www.europages.co.uk/COMERCIALIZADORA-ENEO-SL/00000004009912-284449001.html
# Scraping: https://www.europages.co.uk/COMPANIA-EUROPEA-EXPORTADORA-DE-VINOS/K30118840-000017166001.html
# Incomplete data for COMPAÑÍA EUROPEA EXPORTADORA DE VINOS at https://www.europages.co.uk/COMPANIA-EUROPEA-EXPORTADORA-DE-VINOS/K30118840-000017166001.html
# Scraping: https://www.europages.co.uk/CONTUCCI-DI-ALAMANNO-CONTUCCI-C-SOCIETA-AGRICOLA-SAS/SEAC000062081-001.html
# Scraping: https://www.europages.co.uk/DEFFRENNES/00000005470359-844463001.html
# Scraping: https://www.europages.co.uk/DENBIES-WINE-ESTATE/GBR030628-001.html
# Scraping: https://www.europages.co.uk/DOMADOR-WINES-AND-LIQUORS/00000005421279-757875001.html
# Error scraping https://www.europages.co.uk/DOMADOR-WINES-AND-LIQUORS/00000005421279-757875001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/DOMAINE-DE-LA-BELLE-ETOILE/00000005454270-001.html
# Incomplete data for DOMAINE DE LA BELLE ETOILE at https://www.europages.co.uk/DOMAINE-DE-LA-BELLE-ETOILE/00000005454270-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-DE-MAS-CARON/00000005499956-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-DE-MONTAIGU/00000005520275-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-FJAUBERT/00000005473278-001.html
# Incomplete data for DOMAINE F.JAUBERT at https://www.europages.co.uk/DOMAINE-FJAUBERT/00000005473278-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-GAEL-MARTIN/00000005476930-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-GRAIN-DORIENT/00000005482152-001.html
# Visit website link not found for DOMAINE GRAIN D'ORIENT
# Scraping: https://www.europages.co.uk/DOMAINE-LE-BOUT-DU-LIEU/00000004655630-001.html
# Scraping: https://www.europages.co.uk/DOMAINE-SPIAGGIA/00000005493729-001.html
# Visit website link not found for DOMAINE SPIAGGIA
# Scraping: https://www.europages.co.uk/DOMAINES-FABRE/FRA018404-00101.html
# Visit website link not found for DOMAINES FABRE
# Scraping: https://www.europages.co.uk/DRINKS-SPIRITS/00000005469013-841992001.html
# Visit website link not found for DRINKS & SPIRITS
# Scraping: https://www.europages.co.uk/DVINS/00000004673346-474788001.html
# Incomplete data for DVINS at https://www.europages.co.uk/DVINS/00000004673346-474788001.html
# Scraping: https://www.europages.co.uk/ECCELSIA-DI-FEDERICA-GRISO/00000005421265-757840001.html
# Scraping: https://www.europages.co.uk/EGIAZKI-SPIRITUEUX/00000005508622-001.html
# Incomplete data for EGIAZKI SPIRITUEUX at https://www.europages.co.uk/EGIAZKI-SPIRITUEUX/00000005508622-001.html
# Scraping: https://www.europages.co.uk/ELECTRON-INDUSTRIAL-MACHINES/00000005414028-751813001.html
# Scraping: https://www.europages.co.uk/ENOLTA-MAPAN-SRL/00000005244996-561424001.html
# Scraping: https://www.europages.co.uk/EPI-EXPORT-PRODOTTI-ITALIANI/00000005556740-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/ETIQUETAS-ADHESIVAS-RECA/00000005246066-562711001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/EUROTEC-SRL-DIV-ELETTROBAR-COLGED/00000004713942-512206001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/EXPO-IBERIA/00000005447980-787679001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/FAMULUS-VERPACKUNGEN-HORST-GMBH/00000004785935-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/FATTORIA-LA-TORRE/SEAC000297637-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/FILIPE-PALHOCA-VINHOS-LDA/00000005338731-637377001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/FOOD-BEVERAGE-ASSOCIATES-LTD/00000005271447-586037001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GAEC-TERRE-DE-GHAYA/00000005547009-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GENERAL-STORES/BEL090916-00101.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GIMAR-SRL/SEAC005464044-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GIRLINGER-CO-GESMBH/00000005343009-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GLOBAL-ALIMENT-TRADE/00000005505850-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GRUPO-CRA-JUICE/ESP190473-000019614001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/GUSTI-DITALIA-SRL/00000003631125-89165001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/HAMPER-LOUNGE/00000005454106-798829001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/HAMPSHIRE-FARE/00000004351286-001.html
# Visit website link not found for N/A
# Scraping: https://www.europages.co.uk/HAUSSMANN-FAMILLE/00000004660581-001.html
# Incomplete data for HAUSSMANN FAMILLE at https://www.europages.co.uk/HAUSSMANN-FAMILLE/00000004660581-001.html
# Scraping: https://www.europages.co.uk/HELEXO-GREEK-WINESBEER-SPIRITS/00000005355738-653979001.html
# Scraping: https://www.europages.co.uk/HERDADE-DO-CARVALHAL-SOCIEDADE-VITIVINICOLA-DE-PORTALEGRE-UNIPESSOAL-LDA/00000004590359-001.html
# Incomplete data for HERDADE DO CARVALHAL -SOCIEDADE VITIVINICOLA DE PORTALEGRE UNIPESSOAL LDA. at https://www.europages.co.uk/HERDADE-DO-CARVALHAL-SOCIEDADE-VITIVINICOLA-DE-PORTALEGRE-UNIPESSOAL-LDA/00000004590359-001.html
# Scraping: https://www.europages.co.uk/HILLEBRANDT-GLAS/00000004619456-429412001.html
# Scraping: https://www.europages.co.uk/HORN-KARTONAGEN-GMBH/AUT043274-00101.html
# Scraping: https://www.europages.co.uk/HORST-WALBERG-TROCKENFRUCHT-IMPORT-GMBH/DEU315805-00101.html
# Incomplete data for HORST WALBERG TROCKENFRUCHT IMPORT GMBH at https://www.europages.co.uk/HORST-WALBERG-TROCKENFRUCHT-IMPORT-GMBH/DEU315805-00101.html
# Scraping: https://www.europages.co.uk/HUCATRANS-HUMANEZ-Y-CALACO-SL/ESP188686-000017392001.html
# Scraping: https://www.europages.co.uk/ID-LABO/FRA340561-001.html
# Scraping: https://www.europages.co.uk/ITALIAN-WINE-SHOPPING-DI-LUCA-LATTENE/00000004622960-431450001.html
# Incomplete data for ITALIAN WINE SHOPPING DI LUCA LATTENE at https://www.europages.co.uk/ITALIAN-WINE-SHOPPING-DI-LUCA-LATTENE/00000004622960-431450001.html
# Scraping: https://www.europages.co.uk/ITALYABROADCOM/GBR281320-6099001.html
# Scraping: https://www.europages.co.uk/ITOCHU-ITALIANA/SEAC000181674-001.html
# Scraping: https://www.europages.co.uk/J-M-GONCALVES-TANOARIA-LDA/PRT017083-00101.html
# Scraping: https://www.europages.co.uk/JETLAB-LLC/00000005431385-001.html
# Error scraping https://www.europages.co.uk/JETLAB-LLC/00000005431385-001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/KRESPA/00000005437539-776670001.html
# Scraping: https://www.europages.co.uk/LA-CENTRALE-DES-VINS/00000003849977-168149001.html
# Scraping: https://www.europages.co.uk/LA-FATTORIA-SULLA-LUNA/00000004711249-510403001.html
# Visit website link not found for LA FATTORIA SULLA LUNA
# Scraping: https://www.europages.co.uk/LA-MARE-WINE-ESTATE/00000004263910-001.html
# Scraping: https://www.europages.co.uk/LE-COUSTELOUS/00000005493850-001.html
# Scraping: https://www.europages.co.uk/LES-CAVES-DE-MON-PERE/FRA486535-832389001.html
# Scraping: https://www.europages.co.uk/LEST-TRADING-LDA-PORT-LINE/00000003725407-115260001.html
# Scraping: https://www.europages.co.uk/LIEPAJAS-PAPIRS/LVA011207-00101.html
# Scraping: https://www.europages.co.uk/LLENASNATURCORK/00000003690523-000020633001.html
# Scraping: https://www.europages.co.uk/LMHWINES-LDA/00000005379599-693940001.html
# Scraping: https://www.europages.co.uk/LUSO-BARREL/00000005331321-628655001.html
# Scraping: https://www.europages.co.uk/MAISON-RIVIERE/FRA053452-00101.html
# Incomplete data for MAISON RIVIERE at https://www.europages.co.uk/MAISON-RIVIERE/FRA053452-00101.html
# Scraping: https://www.europages.co.uk/MARCO-MORA-CENTRIFUGHE-INDUSTRIALI-USATE/SEAC000572616-001.html
# Scraping: https://www.europages.co.uk/MARQUES-DE-CACERES/00000005449114-001.html
# Scraping: https://www.europages.co.uk/MH-WINES/00000005472857-848800001.html
# Scraping: https://www.europages.co.uk/MORELLAIA-VINEYARDS/00000005471919-847404001.html
# Incomplete data for MORELLAIA VINEYARDS at https://www.europages.co.uk/MORELLAIA-VINEYARDS/00000005471919-847404001.html
# Scraping: https://www.europages.co.uk/MORITEM-SRL/00000004702291-001.html
# Incomplete data for MORI-TEM SRL at https://www.europages.co.uk/MORITEM-SRL/00000004702291-001.html
# Scraping: https://www.europages.co.uk/MYALCOLZERO/00000005499802-001.html
# Visit website link not found for MYALCOLZERO
# Scraping: https://www.europages.co.uk/OS-SALEIROS/00000003870521-167037001.html
# Scraping: https://www.europages.co.uk/PACKMARKT/00000005278960-592278001.html
# Scraping: https://www.europages.co.uk/PEPINIERES-VITICOLES-DAYDE-PHILIPPE/ODA01591757-000020600001.html
# Error scraping https://www.europages.co.uk/PEPINIERES-VITICOLES-DAYDE-PHILIPPE/ODA01591757-000020600001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/PINTO-RAPOSO-WINES/00000005287160-001.html
# Incomplete data for PINTO RAPOSO WINES at https://www.europages.co.uk/PINTO-RAPOSO-WINES/00000005287160-001.html
# Scraping: https://www.europages.co.uk/PRUNEAUX-DE-MENET/LFR000277-000017502001.html
# Visit website link not found for PRUNEAUX DE MENET
# Scraping: https://www.europages.co.uk/QUESOS-ROCINANTE-SL/00000005404743-737498001.html
# Scraping: https://www.europages.co.uk/QUINTA-DA-FONTE-DO-LOBO-SOCIEDADE-AGRICOLA-LDA/00000005459566-826292001.html
# Scraping: https://www.europages.co.uk/REGUTA-DI-ANSELMI-GIUSEPPE-E-LUIGI-SOC-AGRICOLA-SS/00000005250608-565997001.html
# Scraping: https://www.europages.co.uk/RENDA/00000004925034-546943001.html
# Scraping: https://www.europages.co.uk/RUI-ROBOREDO-MADEIRA-VINHOS-SA/00000004541248-001.html
# Scraping: https://www.europages.co.uk/SANKS/00000005504395-001.html
# Incomplete data for SANKS at https://www.europages.co.uk/SANKS/00000005504395-001.html
# Scraping: https://www.europages.co.uk/SAPURITU-FOOD-TRADE/00000004635054-442952001.html
# Incomplete data for SAPURITU FOOD TRADE at https://www.europages.co.uk/SAPURITU-FOOD-TRADE/00000004635054-442952001.html
# Scraping: https://www.europages.co.uk/SARL-MENARD/00000005450045-791852001.html
# Visit website link not found for SARL MENARD
# Scraping: https://www.europages.co.uk/SCE-MORIZE-PERE-ET-FILS/FRA019076-00101.html
# Scraping: https://www.europages.co.uk/SCEA-DOMAINE-TOUR-CAMPANETS/00000005484654-001.html
# Incomplete data for SCEA DOMAINE TOUR CAMPANETS at https://www.europages.co.uk/SCEA-DOMAINE-TOUR-CAMPANETS/00000005484654-001.html
# Scraping: https://www.europages.co.uk/SCEV-FAGOTDAPREMONT/00000005432872-771315001.html
# Error scraping https://www.europages.co.uk/SCEV-FAGOTDAPREMONT/00000005432872-771315001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/SOBAC/FRA267415-00101.html
# Scraping: https://www.europages.co.uk/SOBREDOS-PRODUCAO-E-COMERCIO-DE-VINHOS-LDA-ANETO-WINES/00000004527468-001.html
# Scraping: https://www.europages.co.uk/SOCIETA-COOPERATIVA-SOCIALE-AMA/00000005365783-665524001.html
# Error scraping https://www.europages.co.uk/SOCIETA-COOPERATIVA-SOCIALE-AMA/00000005365783-665524001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/STANLAKE-PARK-WINE-ESTATE-LTD/00000004099367-001.html
# Scraping: https://www.europages.co.uk/STEWART-HILL-WALKER/00000005495399-001.html
# Visit website link not found for STEWART HILL WALKER
# Scraping: https://www.europages.co.uk/STOLZLE-LAUSITZ-GMBH/DEU014984-00101.html
# Scraping: https://www.europages.co.uk/TASTAVIN-VENTE-DE-VIN-EN-LIGNE/00000004730257-529549001.html
# Incomplete data for TASTAVIN VENTE DE VIN EN LIGNE at https://www.europages.co.uk/TASTAVIN-VENTE-DE-VIN-EN-LIGNE/00000004730257-529549001.html
# Scraping: https://www.europages.co.uk/THE-GOURMET-CORP/00000003964281-001.html
# Error scraping https://www.europages.co.uk/THE-GOURMET-CORP/00000003964281-001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/THE-HOLY-SPIRITUS-BV/00000005418472-754329001.html
# Scraping: https://www.europages.co.uk/TRADINGSHOP/00000005367403-001.html
# Error scraping https://www.europages.co.uk/TRADINGSHOP/00000005367403-001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/TUTTOGHIACCIO/SEAC005806213-002.html
# Incomplete data for TUTTOGHIACCIO at https://www.europages.co.uk/TUTTOGHIACCIO/SEAC005806213-002.html
# Scraping: https://www.europages.co.uk/VIGNERONS-DOLERON/00000005376337-688480001.html
# Scraping: https://www.europages.co.uk/VIGNOBLES-KANDLER/00000005481783-001.html
# Incomplete data for VIGNOBLES KANDLER at https://www.europages.co.uk/VIGNOBLES-KANDLER/00000005481783-001.html
# Scraping: https://www.europages.co.uk/VILLA-CANTHUS-AZVINICOLA/SEAC005748416-001.html
# Scraping: https://www.europages.co.uk/VIN-SUR-LOIRE/00000005455596-801311001.html
# Scraping: https://www.europages.co.uk/VINI-SUD-SHOP/00000005365250-665202001.html
# Incomplete data for VINI SUD SHOP at https://www.europages.co.uk/VINI-SUD-SHOP/00000005365250-665202001.html
# Scraping: https://www.europages.co.uk/VINODELICE/00000005549006-001.html
# Scraping: https://www.europages.co.uk/VINUMWORLD-GMBH/00000005404856-737725001.html
# Incomplete data for VINUMWORLD GMBH at https://www.europages.co.uk/VINUMWORLD-GMBH/00000005404856-737725001.html
# Scraping: https://www.europages.co.uk/VITIKIT-LIMITED/00000005384408-700762001.html
# Scraping: https://www.europages.co.uk/VITINFRUITS-DOO/00000004705174-502912001.html
# Scraping: https://www.europages.co.uk/WEINGESELLSCHAFT-RUYTER-AST-GMBH/00000004666601-467800001.html
# Scraping: https://www.europages.co.uk/WEINKONTOR-FREUND-GMBH/00000005354884-001.html
# Scraping: https://www.europages.co.uk/WINE-IN-AZORES/00000005250612-566024001.html
# Scraping: https://www.europages.co.uk/WINE-ONLINE/00000004070391-001.html
# Incomplete data for WINE ONLINE at https://www.europages.co.uk/WINE-ONLINE/00000004070391-001.html
# Scraping: https://www.europages.co.uk/WINE-PARTNERS/00000004667446-001.html
# Incomplete data for WINE PARTNERS at https://www.europages.co.uk/WINE-PARTNERS/00000004667446-001.html
# Scraping: https://www.europages.co.uk/WINE-SHOP-ONLINE/00000005389809-709266001.html
# Error scraping https://www.europages.co.uk/WINE-SHOP-ONLINE/00000005389809-709266001.html: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.139)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7832a3d85+79397]
# 	GetHandleVerifier [0x0x7ff7832a3de0+79488]
# 	(No symbol) [0x0x7ff78304c0fa]
# 	(No symbol) [0x0x7ff783048ea0]
# 	(No symbol) [0x0x7ff783039cb9]
# 	(No symbol) [0x0x7ff78303ba71]
# 	(No symbol) [0x0x7ff783039fd6]
# 	(No symbol) [0x0x7ff783039a36]
# 	(No symbol) [0x0x7ff7830396fa]
# 	(No symbol) [0x0x7ff7830372cb]
# 	(No symbol) [0x0x7ff783037b4c]
# 	(No symbol) [0x0x7ff7830500aa]
# 	(No symbol) [0x0x7ff7830f40ee]
# 	(No symbol) [0x0x7ff7830cb19a]
# 	(No symbol) [0x0x7ff7830f3344]
# 	(No symbol) [0x0x7ff7830caf73]
# 	(No symbol) [0x0x7ff7830941b1]
# 	(No symbol) [0x0x7ff783094f43]
# 	GetHandleVerifier [0x0x7ff78356e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff78356831d+2980797]
# 	GetHandleVerifier [0x0x7ff783587e0d+3110573]
# 	GetHandleVerifier [0x0x7ff7832bd6de+184190]
# 	GetHandleVerifier [0x0x7ff7832c516f+215567]
# 	GetHandleVerifier [0x0x7ff7832ac974+115220]
# 	GetHandleVerifier [0x0x7ff7832acb29+115657]
# 	GetHandleVerifier [0x0x7ff783293268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2e97e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2fc7c34c+44]
#
# Scraping: https://www.europages.co.uk/WINENOT/00000003856439-156303001.html
# Incomplete data for WINE-NOT at https://www.europages.co.uk/WINENOT/00000003856439-156303001.html
# Scraping: https://www.europages.co.uk/WINES-TREE/FRA597515-00101.html
# Visit website link not found for WINES TREE
# Scraping: https://www.europages.co.uk/en/company/bodega-y-vinedos-milenico-sl-22301309
# Scraping: https://www.europages.co.uk/en/company/bodegas-bocopa-22304911
# Scraping: https://www.europages.co.uk/en/company/bodegas-bohorquez-22311163
# Incomplete data for Bodegas Bohórquez at https://www.europages.co.uk/en/company/bodegas-bohorquez-22311163
# Scraping: https://www.europages.co.uk/en/company/bodegues-visendra-22305414
# Scraping: https://www.europages.co.uk/en/company/corchos-del-pigar-22310396
# Scraping: https://www.europages.co.uk/en/company/engage-srl-22302313
# Scraping: https://www.europages.co.uk/en/company/lantos-muanyagfeldolgozo-kft-22281757
# Scraping: https://www.europages.co.uk/en/company/le-chant-des-caves-22290211
# Incomplete data for Le Chant des Caves at https://www.europages.co.uk/en/company/le-chant-des-caves-22290211
# Scraping: https://www.europages.co.uk/en/company/near-trade-22210051
# Scraping: https://www.europages.co.uk/en/company/sivac-sa-22304692
# Scraping: https://www.europages.co.uk/en/company/tapones-morato-saez-22299188
# Incomplete data for Tapones Morato Saez at https://www.europages.co.uk/en/company/tapones-morato-saez-22299188
# Scraping: https://www.europages.co.uk/en/company/tipografia-cartotecnica-grafostil-22295064
# Saved output to outputs\emails_wine.csv
